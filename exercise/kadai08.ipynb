# %% [markdown]
# # 準備
# 課題を始める前に，以下のコード（コマンド）を実行して，ファイル「exam.txt」をノートブックにダウンロードする．

# %%
# !curl -L -o exam.txt https://bit.ly/4ddBB2N

# %% [markdown]
# # 第8回課題
# 以下の要件を満たすコードを作成しなさい．
#
# **＜要件＞**
# *  すでに入力されているコードは削除・変更しない
# *  コメントはすべて削除する
# *  「exam.txt」の各行にある数値データを小さい順（昇順）で並べ替えたものを「rank.txt」というファイルに書き込むコードを作成する
# *  4行目以外には空行を作らない
# *  指定した書式にノートブック名を変更する

# %%
with open('exam.txt', 'r', encoding='utf-8') as e:
    results = # ここにコードを記述
    # ここにコードを記述

with # ここにコードを記述
    for r in results:
        f.write(f'{r}\n')
