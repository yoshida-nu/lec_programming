# %% [markdown]
# # 第3回課題
# メソッドを利用して以下の実行結果となるコードを作成しなさい．
#
# <img src="./fig/03_kadai_result.png" width="500">
#
# コードに対する要件は以下の通り．
# *  すでに入力されているコードは削除・変更しない
# *  コメントはすべて削除する
# *  2行目：メソッドを使って score の末尾に整数型（int）の「68」を追加するコードを記述
# *  4行目：メソッドを使って score の要素「89」を削除するコードを記述
# *  6行目：メソッドを使って score の要素を昇順（小さい順）に並び替えるコードを記述
# *  空行を作らない
# *  指定した書式にノートブック名を変更する

# %%
score = [87, 71, 75, 95, 82, 66, 70, 89, 98]
#ここに score の末尾に整数型（int）の「68」を追加するコードを記述
print(score)
#ここに score の要素「89」を削除するコードを記述
print(score)
#ここに score の要素を昇順（小さい順）に並び替えるコードを記述
print(score)
