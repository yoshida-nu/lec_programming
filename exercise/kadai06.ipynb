# %% [markdown]
# # 第6回課題
#
# 以下の要件を満たすコードを作成しなさい．
#
# **＜要件＞**
# *  すでに入力されているコードは削除・変更しない
# *  コメントはすべて削除する
# *  以下の動作をする関数`even_or_odd`を1～5行目で定義する
# >*  実引数である整数を仮引数`n`で受け取る
# >*  受け取った値が偶数であれば3行目を実行する
# >*  一方，奇数であれば5行目を実行する関数をで定義する
# *  6行目以外には空行を作らない
# *  コードを実行した状態（実行結果を表示した状態）で提出する
# *  指定した書式にノートブック名を変更する

# %%
def # ここにコードを記述
    # ここにコードを記述
        print(f'{n}は偶数です。')
    # ここにコードを記述
        print(f'{n}は奇数です。')

even_or_odd(2)
even_or_odd(7)
even_or_odd(-6)
